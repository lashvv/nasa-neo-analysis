# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../data/raw/neo_close_approaches_raw.csv')

# %%
df.head()
# Out:
#           des orbit_id            jd                 cd      dist  dist_min  \
# 0      509352       64  2.415024e+06  1900-Jan-04 22:25  0.009632  0.009625
# 1  2014 SC324       57  2.415031e+06  1900-Jan-11 01:07  0.039964  0.039904
# 2  2012 UK171       54  2.415032e+06  1900-Jan-12 23:02  0.049706  0.049578
# 3    2024 BA5        3  2.415045e+06  1900-Jan-25 06:22  0.026434  0.011310
# 4    2024 BW1        6  2.415045e+06  1900-Jan-25 19:29  0.037979  0.010125
#
#    dist_max      v_rel      v_inf t_sigma_f      h  diameter  diameter_sigma  \
# 0  0.009639   8.686710   8.654806     00:02  20.14       NaN             NaN
# 1  0.040025  10.652382  10.646122     00:18  24.39       NaN             NaN
# 2  0.049834   7.153496   7.145999     00:05  24.46       NaN             NaN
# 3  0.198644   8.436204   8.424247     21:33  26.02       NaN             NaN
# 4  0.089436   6.339787   6.328711   4_11:16  25.12       NaN             NaN
#
#               fullname
# ...

# %%
print(df.shape)
print(df.dtypes)
print(df.isnull().sum())
# Out:
# (51122, 14)
# des                   str
# orbit_id              str
# jd                float64
# cd                    str
# dist              float64
# dist_min          float64
# dist_max          float64
# v_rel             float64
# v_inf             float64
# t_sigma_f             str
# h                 float64
# diameter          float64
# diameter_sigma    float64
# fullname              str
# dtype: object
# des                   0
# orbit_id              0
# jd                    0
# cd                    0
# dist                  0
# dist_min              0
# dist_max              0
# v_rel                 0
# v_inf                25
# t_sigma_f             0
# h                    10
# diameter          49634
# diameter_sigma    49785
# fullname              0
# dtype: int64

# %% [markdown]
# ### Seeing if its better to drop v_inf column or not

# %%
df[df['v_inf'].isna()]
# Out:
#               des orbit_id            jd                 cd      dist  \
# 7696    2012 TF79       18  2.439511e+06  1967-Jan-20 03:00  0.035501
# 13794  2006 RH120       54  2.453990e+06  2006-Sep-11 07:40  0.005611
# 13904  2006 RH120       54  2.454104e+06  2007-Jan-03 18:02  0.003566
# 13979  2006 RH120       54  2.454185e+06  2007-Mar-25 12:32  0.002363
# 14028  2006 RH120       54  2.454266e+06  2007-Jun-14 05:31  0.001851
# 19194    2020 CD3       27  2.458015e+06  2017-Sep-18 06:00  0.001339
# 19522    2020 CD3       27  2.458094e+06  2017-Dec-06 09:22  0.001662
# 19742    2020 CD3       27  2.458169e+06  2018-Feb-19 08:28  0.001489
# 19962    2020 CD3       27  2.458248e+06  2018-May-09 13:48  0.000172
# 20122    2020 CD3       27  2.458340e+06  2018-Aug-09 12:37  0.002042
# 20352    2020 CD3       27  2.458418e+06  2018-Oct-26 00:10  0.002152
# 20611    2020 CD3       27  2.458500e+06  2019-Jan-16 17:12  0.001084
# ...

# %% [markdown]
# ### Seeing if its better to drop h column or not

# %%
df[df['h'].isna()]
# Out:
#             des orbit_id            jd                 cd      dist  dist_min  \
# 1897       289P  K192/12  2.422301e+06  1919-Dec-08 13:17  0.047236  0.047222
# 2649         7P       33  2.425058e+06  1927-Jun-26 19:36  0.039379  0.039379
# 4951       322P       10  2.432287e+06  1947-Apr-11 04:00  0.047438  0.046433
# 8653   2024 OC2        8  2.441897e+06  1973-Aug-02 20:39  0.047996  0.044206
# 12276   1999 J6        9  2.451342e+06  1999-Jun-12 05:23  0.011956  0.002386
# 13075      289P  K192/12  2.452986e+06  2003-Dec-12 01:45  0.025040  0.025018
# 18075      252P   K212/2  2.457469e+06  2016-Mar-21 13:16  0.035634  0.035633
# 18078      460P       60  2.457470e+06  2016-Mar-22 15:31  0.023665  0.023665
# 37348       15P  K213/18  2.473755e+06  2060-Oct-22 17:23  0.033433  0.033418
# 43961     73P-B  K061/24  2.491557e+06  2109-Jul-20 21:44  0.035592  0.034722
#
#        dist_max      v_rel      v_inf t_sigma_f   h  diameter  diameter_sigma  \
# ...

# %% [markdown]
# ### Check if any row is fully duplicated,

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### Values that are technically present but look wrong:

# %%
df[['dist', 'v_rel', 'v_inf', 'h']].describe()
# Out:
#                dist         v_rel         v_inf             h
# count  51122.000000  51122.000000  51097.000000  51112.000000
# mean       0.027387     10.301089     10.274646     25.219717
# std        0.013987      5.271150      5.279136      2.549173
# min        0.000044      0.073451      0.125474     14.080000
# 25%        0.015927      6.574564      6.543646     23.930000
# 50%        0.028381      9.313345      9.286082     25.600000
# 75%        0.039425     12.999827     12.976221     26.900000
# max        0.050000     42.918833     42.913640     34.060000

# %%
df['t_sigma_f'].unique()[:30]
# Out:
# <StringArray>
# [  '00:02',   '00:18',   '00:05',   '21:33', '4_11:16',   '00:03',   '00:34',
#    '14:49', '3_02:30',   '00:31', '< 00:01', '9_08:41', '3_20:52', '5_06:04',
#  '6_06:31',   '17:21', '2_05:33', '8_13:42',   '01:15', '8_00:04',   '02:46',
#  '3_06:39', '4_01:16',   '02:26',   '23:01', '3_04:03',   '18:52', '5_21:15',
#    '14:28', '1_13:17']
# Length: 30, dtype: str

# %% [markdown]
# ## Saw the pattern in missing h values.
# ### all of them are commets

# %%
df[df['des'].astype('str').str.contains('P/') | df['fullname'].str.contains('P/', na=False)]
# Out:
#             des orbit_id            jd                 cd      dist  dist_min  \
# 1897       289P  K192/12  2.422301e+06  1919-Dec-08 13:17  0.047236  0.047222
# 2649         7P       33  2.425058e+06  1927-Jun-26 19:36  0.039379  0.039379
# 4951       322P       10  2.432287e+06  1947-Apr-11 04:00  0.047438  0.046433
# 8653   2024 OC2        8  2.441897e+06  1973-Aug-02 20:39  0.047996  0.044206
# 12276   1999 J6        9  2.451342e+06  1999-Jun-12 05:23  0.011956  0.002386
# 13075      289P  K192/12  2.452986e+06  2003-Dec-12 01:45  0.025040  0.025018
# 18075      252P   K212/2  2.457469e+06  2016-Mar-21 13:16  0.035634  0.035633
# 18078      460P       60  2.457470e+06  2016-Mar-22 15:31  0.023665  0.023665
# 37348       15P  K213/18  2.473755e+06  2060-Oct-22 17:23  0.033433  0.033418
# 43961     73P-B  K061/24  2.491557e+06  2109-Jul-20 21:44  0.035592  0.034722
#
#        dist_max      v_rel      v_inf t_sigma_f   h  diameter  diameter_sigma  \
# ...
